# %%
print("iterator")
# Out:
# iterator

# %%
my_list=[1,2,3,5,6,7,8,9]
iterator=iter(my_list)
try:

    print(iterator)
    print(next(iterator))
    print(next(iterator))
    print(next(iterator))
    print(next(iterator))
    print(next(iterator))
    print(next(iterator))
    print(next(iterator))
    print(next(iterator))
    print(next(iterator))

except StopIteration:
    print("iteration completet")
# Out:
# <list_iterator object at 0x000002839F77F6A0>
# 1
# 2
# 3
# 5
# 6
# 7
# 8
# 9
# iteration completet

# %%
def square(x):
    for i in range(3):
        yield i**2
    print("Iteration ended")


    
gen=square(3)
for i in square(3):
    print(i)
# Out:
# 0
# 1
# 4
# Iteration ended

# %%
next(gen)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 next(gen)
#
# StopIteration:

# %%
def read_file(filepath):
    with open(filepath,'r') as file:
        for line in file:
            yield line

filepath="large.txt"
gen1=read_file(filepath)

# %%
for i in read_file(filepath):
    print(i.strip())
# Out:
# hello
# my name is soham
# i am 21 years old
# i am smart and hardworking and lucky

# %%
print(next(gen1))
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 print(next(gen1))
#
# StopIteration:
