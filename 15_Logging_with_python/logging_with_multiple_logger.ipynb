# %% [markdown]
# LOGGING WITH MULTIPLE LOGGERS

# %%
import logging
#create a logger for module1
logger1=logging.getLogger("module1")
logger1.setLevel(logging.DEBUG)

#create a logger for module 2
logger2=logging.getLogger("module2")
logger2.setLevel(logging.WARNING) 

logging.basicConfig(
    
    level=logging.DEBUG,
    format='%(asctime)s-%(name)s-%(levelname)s-%(message)s',
    datefmt='%Y-%m-%d %H:%M:%S',
    force=True
)

# %%
#log messages with different loggers
logger1.debug('this is a debug message for module1')
logger2.warning('this is a warning message for module2')
logger2.error('this is an error message for module 2')
# Out:
# 2026-05-30 13:02:00-module1-DEBUG-this is a debug message for module1
# 2026-05-30 13:02:00-module2-WARNING-this is a warning message for module2
# 2026-05-30 13:02:00-module2-ERROR-this is an error message for module 2
