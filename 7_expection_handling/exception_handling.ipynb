# %%
print("Exception")
# Out:
# Exception

# %%
try:
    result=1/2
    a=b
except ZeroDivisionError as Zd:
    print(Zd)

except Exception as ed:
    print(ed)
# Out:
# name 'b' is not defined

# %%
try:
    num=int(input("Enter a number:"))
    result=10/num

except ValueError:
    print("the number is not a valid number")

except ZeroDivisionError:
    print("the denomninator should be greater than zero")

except Exception as ed:
    print(ed)

else:
    print(result)
# Out:
# 2.0
